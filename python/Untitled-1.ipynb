# %% [markdown]
# # AMAZON WEB SCRAPER

# %%
# IMPORT LIBRARIES
from bs4 import BeautifulSoup
import requests
import smtplib
import time 
import datetime
import pandas as pd

# %%
# connect to website
url = "https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)","Accept-Language": "en-US,en;q=0.9",}
page = requests.get(url, headers=headers) # get page
soup1 = BeautifulSoup(page.content, "html.parser") # get content
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")  # prettify content

# specify what we want
title= soup2.find('span',id='productTitle').get_text(strip=True)
print(title)
# Out:
# Got Data Funny Business Data Analyst T-Shirt

# %%
# specify what we want
title= soup2.find(id='productTitle').get_text()
print(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 # specify what we want
# ----> 2 title= soup2.find(id='productTitle').get_text()
#       3 print(title)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
